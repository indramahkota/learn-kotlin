// %%
data class UserEntity(
    var id: Long = 0,
    val userId: Long,
    val avatarUrl: String?,
    val name: String?,
    val login: String?,
    val bio: String?,
    val followers: Int?,
    val following: Int?,
    val location: String?,
    val email: String?
)

data class UserDto(
    val id: Long,
    val avatarUrl: String?,
    val name: String?,
    val login: String?,
    val bio: String?,
    val followers: Int?,
    val following: Int?,
    val location: String?,
    val email: String?
)

/* User DTO to Entity */
fun UserDto.toUserEntity() = UserEntity(
    userId = id,
    avatarUrl = avatarUrl,
    name = name,
    login = login,
    bio = bio,
    followers = followers,
    following = following,
    location = location,
    email = email
)

fun List<UserDto>.toListUserEntity() =
    this.map {
        it.toUserEntity()
    }

// %%
val fakeUserDto1 = UserDto(
        id = 137,
        avatarUrl = "https://avatars.githubusercontent.com/u/137?v=4",
        name = "Joshua Peek",
        login = "josh",
        bio = null,
        followers = 2351,
        following = 184,
        location = "San Francisco, CA",
        email = null
    )
    val fakeUserDto2 = UserDto(
        id = 54473,
        avatarUrl = "https://avatars.githubusercontent.com/u/54473?v=4",
        name = "Josh Long",
        login = "joshlong",
        bio = "Josh (@starbuxman) is the Spring Developer Advocat...",
        followers = 7955,
        following = 65,
        location = "San Francisco, CA",
        email = null
    )
    val fakeUserDto3 = UserDto(
        id = 6692932,
        avatarUrl = "https://avatars.githubusercontent.com/u/6692932?v=4",
        name = "Joshua Comeau",
        login = "joshwcomeau",
        bio = "Software developer. Makes stuff....",
        followers = 3574,
        following = 25,
        location = "Montreal, QC",
        email = null
    )
    val fakeUserDto4 = UserDto(
        id = 13760,
        avatarUrl = "https://avatars.githubusercontent.com/u/13760?v=4",
        name = "Josh Abernathy",
        login = "joshaber",
        bio = null,
        followers = 2067,
        following = 39,
        location = "The Gem City",
        email = null
    )
    val fakeUserDto5 = UserDto(
        id = 10632,
        avatarUrl = "https://avatars.githubusercontent.com/u/10632?v=4",
        name = "Josh Perez",
        login = "goatslacker",
        bio = null,
        followers = 798,
        following = 127,
        location = "Florida",
        email = null
    )
    val fakeUserDto6 = UserDto(
        id = 3272748,
        avatarUrl = "https://avatars.githubusercontent.com/u/3272748?v=4",
        name = "Captain Pangyo",
        login = "joshua1988",
        bio = null,
        followers = 1191,
        following = 125,
        location = "South Korea",
        email = null
    )
    val fakeUserDto7 = UserDto(
        id = 3231,
        avatarUrl = "https://avatars.githubusercontent.com/u/3231?v=4",
        name = "josh rotenberg",
        login = "joshrotenberg",
        bio = "hi, i'm josh....",
        followers = 44,
        following = 81,
        location = "albany, ca",
        email = null
    )
    val fakeUserDto8 = UserDto(
        id = 3335181,
        avatarUrl = "https://avatars.githubusercontent.com/u/3335181?v=4",
        name = "Josh Goldberg",
        login = "JoshuaKGoldberg",
        bio = "staff web platform @Codecademy 💖✨ prev @microsoft...",
        followers = 887,
        following = 173,
        location = "Brooklyn, NYC",
        email = null
    )
    val fakeUserDto9 = UserDto(
        id = 77495,
        avatarUrl = "https://avatars.githubusercontent.com/u/77495?v=4",
        name = "Josh Cheek",
        login = "JoshCheek",
        bio = null,
        followers = 492,
        following = 9,
        location = "Nomadic",
        email = null
    )
    val fakeUserDto10 = UserDto(
        id = 2578009,
        avatarUrl = "https://avatars.githubusercontent.com/u/2578009?v=4",
        name = "Josh Morony",
        login = "joshuamorony",
        bio = "I create web development tutorials, mostly about I...",
        followers = 707,
        following = 0,
        location = "Adelaide",
        email = null
    )

    fun fakeListRepo(): List<UserDto> = listOf(
        fakeUserDto1,
        fakeUserDto2,
        fakeUserDto3,
        fakeUserDto4,
        fakeUserDto5,
        fakeUserDto6,
        fakeUserDto7,
        fakeUserDto8,
        fakeUserDto9,
        fakeUserDto10,
    )

// %%
val list = fakeListRepo()

list.forEach {
    println(
        """
            assertEquals(${it.id}, user?.userId)
            assertEquals(${it.name}, user?.name)
            assertEquals(${it.avatarUrl}, user?.avatarUrl)
            assertEquals(${it.login}, user?.login)
            assertEquals(${it.followers}, user?.followers)
            assertEquals(${it.following}, user?.following)
            assertEquals(${it.location}, user?.location)
            assertEquals(${it.email}, user?.email)
        """
    )
}
// Out:
//             assertEquals(137, user?.userId)
//             assertEquals(Joshua Peek, user?.name)
//             assertEquals(https://avatars.githubusercontent.com/u/137?v=4, user?.avatarUrl)
//             assertEquals(josh, user?.login)
//             assertEquals(2351, user?.followers)
//             assertEquals(184, user?.following)
//             assertEquals(San Francisco, CA, user?.location)
//             assertEquals(null, user?.email)
//
//
//             assertEquals(54473, user?.userId)
//             assertEquals(Josh Long, user?.name)
//             assertEquals(https://avatars.githubusercontent.com/u/54473?v=4, user?.avatarUrl)
//             assertEquals(joshlong, user?.login)
//             assertEquals(7955, user?.followers)
//             assertEquals(65, user?.following)
//             assertEquals(San Francisco, CA, user?.location)
//             assertEquals(null, user?.email)
//
//
//             assertEquals(6692932, user?.userId)
// ...
