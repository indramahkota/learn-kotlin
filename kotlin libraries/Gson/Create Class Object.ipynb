// %%
// Using Library
// println(java.nio.file.Paths.get("").toAbsolutePath().toString())
// %use @file[[DIR_PATH]/[LIB_NAME].json]

// %%
%use @file[D:/Programming/Kotlin/learn-kotlin/dependencies/gson.json]
%use @file[D:/Programming/Kotlin/learn-kotlin/dependencies/kasechange.json]

// %%
data class UserResponseDataClass(
    @SerializedName("incomplete_results")
    val incompleteResults: Boolean?,
    @SerializedName("items")
    val items: List<String>,
    @SerializedName("total_count")
    val totalCount: Long?
)

class UserResponseClass {
    @SerializedName("incomplete_results")
    var incompleteResults: Boolean? = false
    @SerializedName("items")
    var items: List<String> = listOf()
    @SerializedName("total_count")
    var totalCount: Long? = 0
}

// %%
val testDataObject = UserResponseDataClass(
    incompleteResults = true,
    items = listOf("1", "2", "3"),
    totalCount = 3
)

println(testDataObject)

val testObject = UserResponseClass().apply {
    incompleteResults = true
    items = listOf("1", "2", "3")
    totalCount = 3
}

println(testObject)
// Out:
// UserResponseDataClass(incompleteResults=true, items=[1, 2, 3], totalCount=3)
// Line_3$UserResponseClass@490fe5a1

// %%
data class User(
    val id: Long,
    val avatarUrl: String,
    val name: String,
    val login: String,
    val bio: String,
    val followers: Int,
    val following: Int,
    val location: String,
    val email: String
)

val githubUsers = """
    [
      {
        "id": 61546756,
        "avatarUrl": "https://avatars.githubusercontent.com/u/61546756?v=4",
        "name": "Galih Indra Firmansyah",
        "login": "galihif",
        "bio": "Android Development Enthusiasts || Google Certified AAD || Software Engineering Student",
        "followers": 21,
        "following": 41,
        "location": "Gunungkidul, Yogyakarta",
        "email": "N/A"
      },
      {
        "id": 44335240,
        "avatarUrl": "https://avatars.githubusercontent.com/u/44335240?v=4",
        "name": "INDRA YUSRIANTO PUTRA ",
        "login": "indrayusriantoputra",
        "bio": "web & android developer ",
        "followers": 0,
        "following": 1,
        "location": "malang ",
        "email": "N/A"
      },
      {
        "id": 68775687,
        "avatarUrl": "https://avatars.githubusercontent.com/u/68775687?v=4",
        "name": "Indra David",
        "login": "ndraa124",
        "bio": "Just interest with programming like web and android and always learn about language programming especially PHP, Javascript, Dart, Java, Kotlin, C#, C++.",
        "followers": 6,
        "following": 5,
        "location": "Jakarta",
        "email": "N/A"
      },
      {
        "id": 40993199,
        "avatarUrl": "https://avatars.githubusercontent.com/u/40993199?v=4",
        "name": "Indra Deva Aji Zakaria",
        "login": "indrad373",
        "bio": "Informatics '19 Telkom University,\r\nAndroid Flutter Developer, UI/UX Designer",
        "followers": 12,
        "following": 9,
        "location": "Bandung",
        "email": "N/A"
      },
      {
        "id": 5094913,
        "avatarUrl": "https://avatars.githubusercontent.com/u/5094913?v=4",
        "name": "Indra Dutt",
        "login": "indradutt",
        "bio": "Android Developer",
        "followers": 0,
        "following": 0,
        "location": "Denver CO",
        "email": "N/A"
      },
      {
        "id": 42020287,
        "avatarUrl": "https://avatars.githubusercontent.com/u/42020287?v=4",
        "name": "Indra Hedar",
        "login": "indrahedar",
        "bio": "Backend Developer, Android Developer",
        "followers": 0,
        "following": 1,
        "location": "Makassar",
        "email": "N/A"
      },
      {
        "id": 34052126,
        "avatarUrl": "https://avatars.githubusercontent.com/u/34052126?v=4",
        "name": "Indra Mahkota",
        "login": "indramahkota",
        "bio": "Android Engineer",
        "followers": 23,
        "following": 19,
        "location": "Pontianak, Indonesia",
        "email": "N/A"
      },
      {
        "id": 8722619,
        "avatarUrl": "https://avatars.githubusercontent.com/u/8722619?v=4",
        "name": "Indra Pradana A",
        "login": "iPradana",
        "bio": "interest : android dev, web dev",
        "followers": 3,
        "following": 2,
        "location": "Surabaya",
        "email": "N/A"
      },
      {
        "id": 86604998,
        "avatarUrl": "https://avatars.githubusercontent.com/u/86604998?v=4",
        "name": "Indra Prajapati",
        "login": "arthur3133",
        "bio": "I am an Android Developer.",
        "followers": 0,
        "following": 0,
        "location": "Ahmedabad",
        "email": "N/A"
      },
      {
        "id": 1942657,
        "avatarUrl": "https://avatars.githubusercontent.com/u/1942657?v=4",
        "name": "Indrajit",
        "login": "indrajitkumar",
        "bio": "Having worked for 12+ years in the industry, I have valuable experience in Android|Python|Machine Learning & Deep Learning practitioner.\r\n\r\n",
        "followers": 1,
        "following": 5,
        "location": "Bangalore",
        "email": "N/A"
      },
      {
        "id": 45512567,
        "avatarUrl": "https://avatars.githubusercontent.com/u/45512567?v=4",
        "name": "Indrajit Sarkar",
        "login": "indraskr9",
        "bio": "Just Started learning Android & Web ;-;",
        "followers": 2,
        "following": 10,
        "location": "N/A",
        "email": "N/A"
      },
      {
        "id": 20751314,
        "avatarUrl": "https://avatars.githubusercontent.com/u/20751314?v=4",
        "name": "Indranil Chatterjee",
        "login": "indracs7",
        "bio": "Android Developer and ML enthusiast.",
        "followers": 5,
        "following": 4,
        "location": "India",
        "email": "N/A"
      },
      {
        "id": 78961083,
        "avatarUrl": "https://avatars.githubusercontent.com/u/78961083?v=4",
        "name": "Indravardhan Reddy M",
        "login": "indravardhanreddy",
        "bio": "Android ||\r\nMachine learning || Web Development\r\n",
        "followers": 1,
        "following": 15,
        "location": "N/A",
        "email": "N/A"
      },
      {
        "id": 32633599,
        "avatarUrl": "https://avatars.githubusercontent.com/u/32633599?v=4",
        "name": "Mochamad Indra Yudha Lakaselindra",
        "login": "IndraYudha22",
        "bio": "Android and Game Programmer",
        "followers": 8,
        "following": 9,
        "location": "N/A",
        "email": "N/A"
      },
      {
        "id": 29093273,
        "avatarUrl": "https://avatars.githubusercontent.com/u/29093273?v=4",
        "name": "indras",
        "login": "indrasan99",
        "bio": "Android Developer",
        "followers": 0,
        "following": 0,
        "location": "Jakarta",
        "email": "N/A"
      }
    ]
""".trimIndent()

val dummyUsers by lazy {
    Gson().fromJson(githubUsers, Array<User>::class.java).toList()
}

dummyUsers.forEach {
    println(
    """
    User(
        id = ${it.id},
        name = "${it.name}",
        bio = "${it.bio}",
        avatarUrl = "${it.avatarUrl}",
        followers = ${it.followers},
        following = ${it.following},
        location = "${it.location}"
    )
    """
    )
}
// Out:
//     User(
//         id = 61546756,
//         name = "Galih Indra Firmansyah",
//         bio = "Android Development Enthusiasts || Google Certified AAD || Software Engineering Student",
//         avatarUrl = "https://avatars.githubusercontent.com/u/61546756?v=4",
//         followers = 21,
//         following = 41,
//         location = "Gunungkidul, Yogyakarta"
//     )
//
//
//     User(
//         id = 44335240,
//         name = "INDRA YUSRIANTO PUTRA ",
//         bio = "web & android developer ",
//         avatarUrl = "https://avatars.githubusercontent.com/u/44335240?v=4",
//         followers = 0,
//         following = 1,
//         location = "malang "
//     )
//
//
//     User(
//         id = 68775687,
//         name = "Indra David",
//         bio = "Just interest with programming like web and android and always learn about language programming especially PHP, Javascript, Dart, Java, Kotlin, C#, C++.",
// ...
